# %% [markdown]
# # Strings

# %%
In Python specifically, strings are a sequence of Unicode Characters

Creating Strings
Accessing Strings
Adding Chars to Strings
Editing Strings
Deleting Strings
Operations on Strings
String Functions

# %%
#Creating Strings

s="helloo"
s = 'hello'
# multiline strings
s = '''hello'''
s = """hello"""
s = str('hello')
print(s)

d="it's raining outside"
print(d)
# Out:
# hello
# it's raining outside

# %%
# Accessing Strings

## Positive Indexing
s="hello world"
print(s[6])
# Out:
# w

# %%
# Negative Indexing

s = 'hello world'
print(s[-3])
# Out:
# r

# %%
# Slicing
##string[start : stop : step]

s = 'hello world'
print(s[1:])
# Out:
# ello world

# %%
s = 'hello world'
print(s[1:6])
# Out:
# ello

# %%
s = 'hello world'
print(s[0:6])
# Out:
# hello

# %%
s = 'hello world'
print(s[0:6],s[:-6:-1])
# Out:
# hello  dlrow

# %%
s="hello world"
print(s[::-1])
# Out:
# dlrow olleh

# %%
s = 'hello world'
print(s[:-6:-1],s[0:6])
# Out:
# dlrow hello

# %%
s="hello world"
print(s[-1:-6:-1])
# Out:
# dlrow

# %%
s="hello world"
print(s[0:11:2]) # 2 steps jump ho rha hai
# Out:
# hlowrd

# %%
s="hello world"
print(s[6:0:-1])
# Out:
# w olle

# %%
s="hello world"
print(s[-5:])
# Out:
# world

# %% [markdown]
# # Editing and Deleting in Strings

# %%
s="hello world"
s[0]="H"

## Python strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 s="hello world"
# ----> 2 s[0]="H"
#       3 print("s")
#
# TypeError: 'str' object does not support item assignment

# %%
s="hello world"
del s  ##del means delete
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 s="hello world"
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %% [markdown]
# ## Operations on Strings
#
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %%
##Arithmetic Operations

print("delhi"+"mumbai")
print("delhi"+" "+"mumbai")
# Out:
# delhimumbai
# delhi mumbai

# %%
##Relational Operations

"delhi"!="delhi"
# Out:
# False

# %%
"mumbai">"pune"

##it is compaired lexiographically
# Out:
# False

# %%
"Pune"<"pune"
# Out:
# True

# %%
##Logical Operations , ##agar characters hai toh true vrna false

"hello" and "world"
# Out:
# 'world'

# %%
"hello" or "world"
# Out:
# 'hello'

# %%
"" and "world"
# Out:
# ''

# %%
"" or "world"
# Out:
# 'world'

# %%
not ""
# Out:
# True

# %%
not "hello"
# Out:
# False

# %%
for i in 'delhi':
  print(i)
# Out:
# d
# e
# l
# h
# i

# %%
for i in "delhi":
  print("pune")
# Out:
# pune
# pune
# pune
# pune
# pune

# %%
"B" in "Bhopal"
# Out:
# True

# %%
"B" not in "Bhopal"
# Out:
# False

# %% [markdown]
# ## Common Functions

# %%
# len
# max
# min
# sorted

# %%
len ("hello")
# Out:
# 5

# %%
max("hello world")
# Out:
# 'w'

# %%
min ("hello world")
# Out:
# ' '

# %%
sorted("hello world")
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %%
sorted("hello world", reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# # Capitalize/Title/Upper/Lower/Swapcase

# %%
s="hello world"
s=(s.capitalize())
print(s)
# Out:
# Hello world

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.swapcase()
# Out:
# 'hELLO WORLD'

# %% [markdown]
# # Count/Find/Index

# %%
"hello my name is nandini soni".count("n")
# Out:
# 5

# %%
"hello my name is nandini soni".find("n")
# Out:
# 9

# %%
"hello my name is nandini soni".index("i")
# Out:
# 14

# %% [markdown]
# # endswith/startswith

# %%
"hello my name is nandini soni".endswith("i")
# Out:
# True

# %%
"hello my name is nandini soni".startswith("i")
# Out:
# False

# %% [markdown]
# # Format

# %%
name="nandini"
gender="female"

"hello my name is {} and i am {}".format(name,gender)
# Out:
# 'hello my name is nandini and i am female'

# %% [markdown]
# # isalnum/ isalpha/ isdigit/ isidentifier

# %%
"nandini1224".isalnum() ## alphabets+numbers
# Out:
# True

# %%
"nandini1224".isalpha() ## only alphabets
# Out:
# False

# %%
"1224".isdigit()
# Out:
# True

# %% [markdown]
# # Split/Join

# %%
"hello my name is nandini soni".split()
# Out:
# ['hello', 'my', 'name', 'is', 'nandini', 'soni']

# %%
'first_name'.isidentifier()
# Out:
# True

# %%
"hello my name is nandini soni".split("name")
# Out:
# ['hello my ', ' is nandini soni']

# %%
" ".join(['hello', 'my', 'name', 'is', 'nandini', 'soni'])
# Out:
# 'hello my name is nandini soni'

# %% [markdown]
# # Replace

# %%
"hello my name is nandini soni".replace("nandini","dudu")
# Out:
# 'hello my name is dudu soni'

# %% [markdown]
# # Strip

# %%
"hello                 ".strip() ## removes extra space after the character ends
# Out:
# 'hello'

# %% [markdown]
# # Example Programs

# %%
s= input("enter a word")
for i in s:
    print(i)
# Out:
# enter a word hello
# h
# e
# l
# l
# o

# %%
# Find the length of a given string without using the len() function


s= input("enter a word")

count =0
for i in s:
    count+=1

print("length of string ",count)
# Out:
# enter a word hello
# length of string  5

# %%
# Find the length of a given string using the len() function

s= input("enter a word")
print(len(s))
# Out:
# enter a word hello
# 5

# %%
s= input("enter email")
pos=(s.index("@"))
print(s[0:pos])
# Out:
# enter email nandinisoni2107@gmail.com
# nandinisoni2107
