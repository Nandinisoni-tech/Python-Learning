# %% [markdown]
# # 1. Python Output

# %%
print('hello')
# Out:
# hello

# %%
print('hello',1,111.444,22)
# Out:
# hello 1 111.444 22

# %%
print('hello',1,111.444,22,sep='/')
# Out:
# hello/1/111.444/22

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end=' - ')
print('world')
# Out:
# hello - world

# %%
print(333+77)
# Out:
# 410

# %% [markdown]
# # 2. Data Types

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('Hello World')
# Out:
# Hello World

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List-> C-> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'name':'Nitish','gender':'Male','weight':70})
# Out:
# {'name': 'Nitish', 'gender': 'Male', 'weight': 70}

# %%
# type
type([1,2,3])
# Out:
# list

# %%
type('hello')
# Out:
# str

# %%
type(1.5555)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # 3. Variables

# %%
name='Dev'
age=12

print(name , age)
# Out:
# Dev 12

# %%
a=17
b=4
print(a+b)
# Out:
# 21

# %%
a,b,c=1,2,3
print(a,b,c)

a=b=c=5
print(a,b,c)
# Out:
# 1 2 3
# 5 5 5

# %%
# Dynamic Typing
a = 5

# Static Typing
int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = 'Dev'
print(a)

# Static Binding
int a = 5

# %% [markdown]
# # Comments

# %%
#hiii
#hellooo

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords

# %%
# Identifiers

# You can't start with a digit
name1 = 'Dev'
print(name1)
# You can use special chars -> _
_ = 'Dev'
print(_)
# identiers can not be keyword

# %% [markdown]
# # 5. User Input

# %%
input()
# Out:
#  hellooo
# 'hellooo'

# %%
input('tell me your name')
# Out:
# tell me your name Nandini
# 'Nandini'

# %%
a=int(input('value of a is '))
b=int(input('value of b is '))
sum = a+b
print(type(a))
# Out:
# value of a is  5
# value of b is  5
# "<class 'int'>"

# %%
print(55+7.2)
# Out:
# 62.2

# %% [markdown]
# # 6.Type Conversion

# %%
#implicit

a=2
b=4.25
sum=a+b  #2.0 + 4.25
print(sum)
print(type(a),type(b))
# Out:
# 6.25
# <class 'int'> <class 'float'>

# %%
#explicit

a=int('2')
b=5
sum=a+b
print(sum)
# Out:
# 7

# %%
#int -> str
str('7')
# Out:
# '7'

# %%
float(5)
# Out:
# 5.0

# %% [markdown]
# # 7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal 
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5 
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal 
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)

# %%
# binary
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 8
b = False + 5

print("a:", a)
print("b:", b)
# Out:
# a: 9
# b: 5

# %%
k = None
a = 5
b = 6
print('Program exe')
# Out:
# Program exe
